# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
weather_data = '../Weather_Database/WeatherPy_Database.csv'

# Display sample data
city_data_df = pd.read_csv(weather_data)
city_data_df
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0          Aklavik      CA  68.2191 -135.0107    -13.00        77
# 1          1        Singleton      AU -32.5667  151.1833     64.33        58
# 2          2  Manavālakurichi      IN   8.1333   77.3000     77.32        74
# 3          3        Ust-Kuyga      RU  70.0167  135.6000    -46.41       100
# 4          4       Batticaloa      LK   7.7102   81.6924     76.64        77
# ..       ...              ...     ...      ...       ...       ...       ...
# 657      657            Lensk      RU  60.7253  114.9278      0.14        93
# 658      658         Cam Ranh      VN  11.9214  109.1591     75.16        73
# 659      659         Pitsunda      GE  43.1592   40.3378     51.98        70
# 660      660              Mao      TD  14.1212   15.3103     67.98        11
# 661      661        Takoradze      GH   4.8845   -1.7554     80.11        82
#
#      Cloudiness  Wind Speed Current Description
# 0           100        8.05     overcast clouds
# 1            97        7.27     overcast clouds
# 2           100       12.33     overcast clouds
# 3            67        1.70       broken clouds
# 4           100        4.97     overcast clouds
# ..          ...         ...                 ...
# 657         100       11.90     overcast clouds
# 658          20        8.05          few clouds
# 659          87        5.12          light rain
# 660           0       11.74           clear sky
# 661           1        7.74           clear sky
#
# [662 rows x 10 columns]

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
maximum_temperature = float(input('What is the maximum desired temperature for your vacation?'))
minimum_temperature = float(input('What is the minimum desired temperature for your vacation?'))

print(maximum_temperature)
print(minimum_temperature)
# Out:
# 90.0
# 70.0

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df[(city_data_df.loc[:,'Max Temp'] >= minimum_temperature) & (city_data_df.loc[:,'Max Temp']<= maximum_temperature)]

# Display sample data
preferred_cities_df
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 2          2  Manavālakurichi      IN   8.1333   77.3000     77.32        74
# 4          4       Batticaloa      LK   7.7102   81.6924     76.64        77
# 9          9          Rikitea      PF -23.1203 -134.9692     76.37        78
# 12        12             Hilo      US  19.7297 -155.0900     78.53        69
# 19        19            Leeds      US  33.5482  -86.5444     73.35        88
# ..       ...              ...     ...      ...       ...       ...       ...
# 652      652             Kuah      MY   6.3265   99.8432     77.00        94
# 653      653     Christchurch      NZ -43.5333  172.6333     76.32        43
# 655      655          Mayumba      GA  -3.4320   10.6554     77.38        88
# 658      658         Cam Ranh      VN  11.9214  109.1591     75.16        73
# 661      661        Takoradze      GH   4.8845   -1.7554     80.11        82
#
#      Cloudiness  Wind Speed Current Description
# 2           100       12.33     overcast clouds
# 4           100        4.97     overcast clouds
# 9            13       16.53          few clouds
# 12           75        5.01       broken clouds
# 19          100       11.50     overcast clouds
# ..          ...         ...                 ...
# 652          20        0.00          few clouds
# 653         100        9.22     overcast clouds
# 655         100        4.23     overcast clouds
# 658          20        8.05          few clouds
# 661           1        7.74           clear sky
#
# [263 rows x 10 columns]

# %%
preferred_cities_df.isna().sum()
# Out:
# City_ID                0
# City                   0
# Country                1
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 2          2  Manavālakurichi      IN   8.1333   77.3000     77.32        74
# 4          4       Batticaloa      LK   7.7102   81.6924     76.64        77
# 9          9          Rikitea      PF -23.1203 -134.9692     76.37        78
# 12        12             Hilo      US  19.7297 -155.0900     78.53        69
# 19        19            Leeds      US  33.5482  -86.5444     73.35        88
# ..       ...              ...     ...      ...       ...       ...       ...
# 652      652             Kuah      MY   6.3265   99.8432     77.00        94
# 653      653     Christchurch      NZ -43.5333  172.6333     76.32        43
# 655      655          Mayumba      GA  -3.4320   10.6554     77.38        88
# 658      658         Cam Ranh      VN  11.9214  109.1591     75.16        73
# 661      661        Takoradze      GH   4.8845   -1.7554     80.11        82
#
#      Cloudiness  Wind Speed Current Description
# 2           100       12.33     overcast clouds
# 4           100        4.97     overcast clouds
# 9            13       16.53          few clouds
# 12           75        5.01       broken clouds
# 19          100       11.50     overcast clouds
# ..          ...         ...                 ...
# 652          20        0.00          few clouds
# 653         100        9.22     overcast clouds
# 655         100        4.23     overcast clouds
# 658          20        8.05          few clouds
# 661           1        7.74           clear sky
#
# [262 rows x 10 columns]

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[['City', 'Country', 'Max Temp', 'Current Description', 'Lat', 'Lng']].copy()
hotel_df
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng
# 2    Manavālakurichi      IN     77.32     overcast clouds   8.1333   77.3000
# 4         Batticaloa      LK     76.64     overcast clouds   7.7102   81.6924
# 9            Rikitea      PF     76.37          few clouds -23.1203 -134.9692
# 12              Hilo      US     78.53       broken clouds  19.7297 -155.0900
# 19             Leeds      US     73.35     overcast clouds  33.5482  -86.5444
# ..               ...     ...       ...                 ...      ...       ...
# 652             Kuah      MY     77.00          few clouds   6.3265   99.8432
# 653     Christchurch      NZ     76.32     overcast clouds -43.5333  172.6333
# 655          Mayumba      GA     77.38     overcast clouds  -3.4320   10.6554
# 658         Cam Ranh      VN     75.16          few clouds  11.9214  109.1591
# 661        Takoradze      GH     80.11           clear sky   4.8845   -1.7554
#
# [262 rows x 6 columns]

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 2    Manavālakurichi      IN     77.32     overcast clouds   8.1333   77.3000
# 4         Batticaloa      LK     76.64     overcast clouds   7.7102   81.6924
# 9            Rikitea      PF     76.37          few clouds -23.1203 -134.9692
# 12              Hilo      US     78.53       broken clouds  19.7297 -155.0900
# 19             Leeds      US     73.35     overcast clouds  33.5482  -86.5444
# ..               ...     ...       ...                 ...      ...       ...
# 652             Kuah      MY     77.00          few clouds   6.3265   99.8432
# 653     Christchurch      NZ     76.32     overcast clouds -43.5333  172.6333
# 655          Mayumba      GA     77.38     overcast clouds  -3.4320   10.6554
# 658         Cam Ranh      VN     75.16          few clouds  11.9214  109.1591
# 661        Takoradze      GH     80.11           clear sky   4.8845   -1.7554
#
#     Hotel Name
# 2
# 4
# 9
# 12
# 19
# ..         ...
# 652
# 653
# 655
# 658
# 661
#
# [262 rows x 7 columns]

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address['features'][0]['properties']['name']
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Manavālakurichi - nearest hotel: No hotel found
# Batticaloa - nearest hotel: Lake View Hotel
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Hilo - nearest hotel: Dolphin Bay Hotel
# Leeds - nearest hotel: Hampton Inn
# Puerto El Triunfo - nearest hotel: Motel Jardín
# Kavieng - nearest hotel: Kavieng Hotel
# Tessalit - nearest hotel: No hotel found
# Chui - nearest hotel: Alerces
# Natal - nearest hotel: Natal Palace Hotel
# Cidreira - nearest hotel: Hotel Castelo
# Vaini - nearest hotel: Keleti International Resort
# Cochabamba - nearest hotel: Hotel Monserrat
# East London - nearest hotel: No hotel found
# Souillac - nearest hotel: Hotel SkylineInn
# Isangel - nearest hotel: Tanna Lodge
# Kroya - nearest hotel: Setia Hotel
# Port Alfred - nearest hotel: No hotel found
# Grand-Santi - nearest hotel: No hotel found
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Hwange - nearest hotel: No hotel found
# Georgetown - nearest hotel: Obsidian Hotel
# Arlit - nearest hotel: No hotel found
# Port Elizabeth - nearest hotel: Waterford Hotel
# Gamba - nearest hotel: No hotel found
# Butaritari - nearest hotel: No hotel found
# Kavaratti - nearest hotel: No hotel found
# Daru - nearest hotel: Kuki
# San Patricio - nearest hotel: Sueño del Sol
# Montes Claros - nearest hotel: Hotel Alvorada
# Kudahuvadhoo - nearest hotel: No hotel found
# Kapaa - nearest hotel: Pono Kai Resort
# Hirara - nearest hotel: 古謝そば屋
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Touros - nearest hotel: Pousada Atlântico
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Namatanai - nearest hotel: Namatanai Hotel
# Atuona - nearest hotel: Pearl Resort
# Mar del Plata - nearest hotel: Nuevo Ostende
# Boyolangu - nearest hotel: No hotel found
# Koulikoro - nearest hotel: No hotel found
# Jacmel - nearest hotel: Hotel L'Amenitie
# Palmas - nearest hotel: Hotel Triângulo Mineiro
# Lábrea - nearest hotel: No hotel found
# Bella Vista - nearest hotel: No hotel found
# San Cristobal - nearest hotel: ChatMan
# Bengkulu - nearest hotel: Dena Hotel
# Eyl - nearest hotel: فندق ايل دابي
# Alice Springs - nearest hotel: Aurora Alice Springs
# Mahébourg - nearest hotel: Grand Bel Air
# Aripuanã - nearest hotel: No hotel found
# Manaure - nearest hotel: hotel palaima
# Faanui - nearest hotel: Oa Oa Lodge
# Sena Madureira - nearest hotel: No hotel found
# Hithadhoo - nearest hotel: Pebbles Inn
# Departamento de Maldonado - nearest hotel: No hotel found
# Weligama - nearest hotel: Basecamp
# Mandera - nearest hotel: Kornesh Hotel and Lodging
# Richards Bay - nearest hotel: Protea Hotel
# Bambous Virieux - nearest hotel: No hotel found
# Uchiza - nearest hotel: No hotel found
# Lázaro Cárdenas - nearest hotel: Hotel Sol del Pacífico
# Quatre Cocos - nearest hotel: Horisun
# Asamankese - nearest hotel: No hotel found
# Ixtapa - nearest hotel: No hotel found
# Beira - nearest hotel: Hotel Savoy
# São Filipe - nearest hotel: Bela Vista
# Pandan - nearest hotel: No hotel found
# Victoria - nearest hotel: Hilltop Boutique Hotel
# Puerto Cabezas - nearest hotel: Hotel Caribe
# Samarai - nearest hotel: No hotel found
# Itarema - nearest hotel: Pousada Oásis
# Alofi - nearest hotel: No hotel found
# The Valley - nearest hotel: CeBlue
# Porto Walter - nearest hotel: No hotel found
# Bela - nearest hotel: No hotel found
# Martaban - nearest hotel: မော်​လ​မြိုင် ဟိုတယ်
# Piracuruca - nearest hotel: No hotel found
# Bucerías - nearest hotel: Royal Decameron Complex
# Avarua - nearest hotel: Paradise Inn
# Bogo - nearest hotel: No hotel found
# Constitucion - nearest hotel: Hotel Roma
# Broome - nearest hotel: Broome Oaks Hotel
# Arraial do Cabo - nearest hotel: No hotel found
# Praia - nearest hotel: Casa Sodadi
# Tiarei - nearest hotel: No hotel found
# Pundaguitan - nearest hotel: No hotel found
# Mitsamiouli - nearest hotel: Hotel le Paradis
# Sorong - nearest hotel: Hotel Membramo Marina
# Key West - nearest hotel: Harborside Hotel & Marina
# Bowen - nearest hotel: Whitsunday Sands Resort
# Bathsheba - nearest hotel: Atlantis Hotel
# São João da Barra - nearest hotel: Pousada Mediterrâneo
# Santa Cruz Cabrália - nearest hotel: Campo Bahia Resort
# Tual - nearest hotel: Suita
# Santa Cruz del Norte - nearest hotel: No hotel found
# San Luis - nearest hotel: Hotel Dos Venados
# Acaraú - nearest hotel: No hotel found
# Sur - nearest hotel: Sur Hotel
# Progreso - nearest hotel: Centro Vacacional Obrero CTM
# Yeppoon - nearest hotel: Blossom's on Seaspray
# Angoche - nearest hotel: Hotel Quirimbas
# Karratha - nearest hotel: Karratha International Hotel
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Gizo Government Station - nearest hotel: Gizo Hotel
# Hobyo - nearest hotel: No hotel found
# Boende - nearest hotel: No hotel found
# Ituporanga - nearest hotel: Clasen Park Hotel
# Azua - nearest hotel: Hotel Montemar
# Ponta do Sol - nearest hotel: Hotel Miranda & Miranda
# Libertador General San Martín - nearest hotel: Hosteria Real Victoria
# Sambava - nearest hotel: Royal Sava Hôtel
# Inverell - nearest hotel: Oxford Hotel
# Catuday - nearest hotel: Nina Anchors Inn
# Katherine - nearest hotel: No hotel found
# Saint-Philippe - nearest hotel: Le Baril
# Carutapera - nearest hotel: No hotel found
# Ankazoabo - nearest hotel: No hotel found
# Rivera - nearest hotel: No hotel found
# Camocim - nearest hotel: Hotel Dunas
# Waingapu - nearest hotel: HOTEL SANDLEWOOD
# Vanimo - nearest hotel: CBC Guesthouse
# Minna - nearest hotel: No hotel found
# Paciran - nearest hotel: No hotel found
# Padang - nearest hotel: losmen Surya
# Mahibadhoo - nearest hotel: Coral View Inn
# Terra Santa - nearest hotel: No hotel found
# Makkah al Mukarramah - nearest hotel: Rehab Al Marwa Hotel 1
# Kahului - nearest hotel: Maui Seaside Hotel
# Puerto Ayacucho - nearest hotel: Hotel VENETUR Amazonas
# Anloga - nearest hotel: Hotel de White House
# Famy - nearest hotel: Gabriel's Resort
# Mbandaka - nearest hotel: Hôtel Epervier
# Miramar - nearest hotel: Calzada Del Sol
# São José da Coroa Grande - nearest hotel: Hotel do Sol
# Portobelo - nearest hotel: Luna Llena Hostal
# Kayes - nearest hotel: No hotel found
# Vao - nearest hotel: Nataiwatch
# Cayenne - nearest hotel: Central Hôtel
# Roboré - nearest hotel: Lajas
# Port Lincoln - nearest hotel: Boston Hotel
# Pontian Kecil - nearest hotel: Hotel Wan Loong
# Dwārka - nearest hotel: The Dwarika Hotel
# Kaeo - nearest hotel: No hotel found
# Charlestown - nearest hotel: Bath Hotel
# Abonnema - nearest hotel: No hotel found
# Salalah - nearest hotel: Muscat International Hotel
# Kununurra - nearest hotel: Kununurra Country Club Resort
# Bonthe - nearest hotel: No hotel found
# Pemangkat - nearest hotel: Hotel Kelapa Gading
# Sinnamary - nearest hotel: Hôtel du fleuve
# Nieuw Amsterdam - nearest hotel: Leonsberg Lodge
# Sabang - nearest hotel: Sabang Hill
# Maxixe - nearest hotel: Hotel Herry
# Teseney - nearest hotel: Costina Hotel Teseney Eritrea
# Luanda - nearest hotel: Hotel Forum
# Loandjili - nearest hotel: Le Raphia Guest House
# Meulaboh - nearest hotel: Hotel Meuligou
# Tartagal - nearest hotel: Majoy
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Grand Gaube - nearest hotel: Coco Villa
# Olinda - nearest hotel: Fidji Motel
# Atambua - nearest hotel: Hotel Matahari
# Port Hedland - nearest hotel: The Esplanade Hotel
# Taoudenni - nearest hotel: No hotel found
# Gadung - nearest hotel: No hotel found
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Todos Santos - nearest hotel: Hotel Casa Tota
# Bandarbeyla - nearest hotel: No hotel found
# Jaguarão - nearest hotel: Hotel Sinuelo
# Kuah - nearest hotel: Langkawi Budget Inn
# Christchurch - nearest hotel: Ibis Hotel Christchurch
# Mayumba - nearest hotel: Résidence Hôtelière Fabso
# Cam Ranh - nearest hotel: Khách sạn Thái Bình
# Takoradze - nearest hotel: Hillcrest
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 2    Manavālakurichi      IN     77.32     overcast clouds   8.1333   77.3000
# 4         Batticaloa      LK     76.64     overcast clouds   7.7102   81.6924
# 9            Rikitea      PF     76.37          few clouds -23.1203 -134.9692
# 12              Hilo      US     78.53       broken clouds  19.7297 -155.0900
# 19             Leeds      US     73.35     overcast clouds  33.5482  -86.5444
# ..               ...     ...       ...                 ...      ...       ...
# 652             Kuah      MY     77.00          few clouds   6.3265   99.8432
# 653     Christchurch      NZ     76.32     overcast clouds -43.5333  172.6333
# 655          Mayumba      GA     77.38     overcast clouds  -3.4320   10.6554
# 658         Cam Ranh      VN     75.16          few clouds  11.9214  109.1591
# 661        Takoradze      GH     80.11           clear sky   4.8845   -1.7554
#
#                     Hotel Name
# 2               No hotel found
# 4              Lake View Hotel
# 9         Chez Bianca & Benoit
# 12           Dolphin Bay Hotel
# 19                 Hampton Inn
# ..                         ...
# 652        Langkawi Budget Inn
# 653    Ibis Hotel Christchurch
# 655  Résidence Hôtelière Fabso
# 658        Khách sạn Thái Bình
# 661                  Hillcrest
#
# [262 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df['Hotel Name'] != 'No hotel found']

# Display sample data
clean_hotel_df
# Out:
#                   City Country  Max Temp Current Description      Lat  \
# 4           Batticaloa      LK     76.64     overcast clouds   7.7102
# 9              Rikitea      PF     76.37          few clouds -23.1203
# 12                Hilo      US     78.53       broken clouds  19.7297
# 19               Leeds      US     73.35     overcast clouds  33.5482
# 25   Puerto El Triunfo      SV     81.52           clear sky  13.2833
# ..                 ...     ...       ...                 ...      ...
# 652               Kuah      MY     77.00          few clouds   6.3265
# 653       Christchurch      NZ     76.32     overcast clouds -43.5333
# 655            Mayumba      GA     77.38     overcast clouds  -3.4320
# 658           Cam Ranh      VN     75.16          few clouds  11.9214
# 661          Takoradze      GH     80.11           clear sky   4.8845
#
#           Lng                 Hotel Name
# 4     81.6924            Lake View Hotel
# 9   -134.9692       Chez Bianca & Benoit
# 12  -155.0900          Dolphin Bay Hotel
# 19   -86.5444                Hampton Inn
# 25   -88.5500               Motel Jardín
# ..        ...                        ...
# 652   99.8432        Langkawi Budget Inn
# 653  172.6333    Ibis Hotel Christchurch
# 655   10.6554  Résidence Hôtelière Fabso
# 658  109.1591        Khách sạn Thái Bình
# 661   -1.7554                  Hillcrest
#
# [179 rows x 7 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_file = 'WeatherPy_vacation.csv'

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_file, index_label='city_data_df Index')

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
map_plot_1 = clean_hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo= True,
    size='Max Temp',
    scale= 1,
    tiles= 'OSM',
    hover_cols=['City', 'Country', 'Current Description'],
    color='City',
    frame_width =1200,
    frame_height = 800
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,Current Description)
